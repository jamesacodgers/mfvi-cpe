# %%
import torch

# %%
d = 5
L = torch.randn((d,d))

X = L @ L.T

torch.linalg.inv(X) # no error so must be pd

print(torch.det(X).log())
print(torch.trace(X.log()))
# Out:
# tensor(4.9190)
# tensor(9.1079)
