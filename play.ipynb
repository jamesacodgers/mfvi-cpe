# %%
import torch
from src.linear_utils import raw_id_ood_violin_plots

# %%
path = "figs/uci/results2/uci_divs_rbf_p=500_l=learned_feat_results.pt"

results = torch.load(path, map_location="cpu", weights_only=False)

# %%
# figs = id_ood_violin_plots(results_id, results_ood, marg_or_joint=True, include_nll=True)
figs = raw_id_ood_violin_plots(results, marg_or_joint=True)

for d, f in figs.items():
    f.show()
# Out:
# /var/folders/rm/lcltb3c50vgc_vn2gmq557hr0000gn/T/ipykernel_48964/3908342096.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()
