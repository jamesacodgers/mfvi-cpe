# %%
import torch
from src.linear_utils import plot_train_test_temp_gap_violins

# %%
path = "figs/uci/uci_divs_rbf_p=5000_l=learned_results.pt"

results = torch.load(path, map_location="cpu", weights_only=False)

results.keys()
# Out:
# dict_keys(['meta', 'temps', 'data'])

# %%
figs = plot_train_test_temp_gap_violins(results, True)

for d, f in figs.items():
    f.show()
# Out:
# /var/folders/rm/lcltb3c50vgc_vn2gmq557hr0000gn/T/ipykernel_28602/738051550.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()
