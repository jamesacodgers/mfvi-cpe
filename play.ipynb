# %%
import torch
from src.linear_utils import id_ood_violin_plots, raw_id_ood_violin_plots

# %%
path = "figs/uci/uci_divs_rbf_p=5000_l=learned_results.pt"

results_id = torch.load(path, map_location="cpu", weights_only=False)

path = "figs/uci/uci_divs_rbf_p=5000_l=learned_ood_feat_results.pt"

results_ood = torch.load(path, map_location="cpu", weights_only=False)

# %%
# figs = id_ood_violin_plots(results_id, results_ood, marg_or_joint=True, include_nll=True)
figs = raw_id_ood_violin_plots(results_id, results_ood, marg_or_joint=True)

for d, f in figs.items():
    f.show()
# Out:
# /var/folders/rm/lcltb3c50vgc_vn2gmq557hr0000gn/T/ipykernel_33418/3359341876.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   f.show()
